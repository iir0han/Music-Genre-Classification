# %%
import pickle
import matplotlib
import os
import xgboost as xgb
from matplotlib import pyplot as plt

# %%
os.chdir('C:\\Users\\iiroh\\Documents\\Projects\\Music Genre Classification\\features\\')
xgb_classifier = pickle.load(open('finalized_model_xbg.pkl','rb'))

# %%
ax = xgb.plot_importance(xgb_classifier, max_num_features=20, height=0.5, show_values=False)
fig = ax.figure
fig.set_size_inches(8, 8)
